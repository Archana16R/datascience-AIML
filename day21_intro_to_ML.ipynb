# %% [markdown]
# Task 1: The Paradigm Shift (Traditional vs. Machine Learning)
#
#  Introduction to Machine Learning
#
# Machine Learning is a method of teaching computers to learn patterns from data instead of explicitly programming every rule. In traditional programming, we provide the computer with input data and fixed rules, and it produces an output. However, in Machine Learning, we provide the computer with input data along with the correct outputs (answers), and the system learns the underlying rules or patterns by itself. Once trained, the model can use those learned patterns to make predictions on new, unseen data. In simple terms, instead of writing rules manually, we allow the computer to discover the rules from data.

# %% [markdown]
# Task 2: The Three Branches of ML
#
# 1. Supervised Learning
#
# Supervised Learning is a type of Machine Learning where the data contains input features and corresponding correct output labels (answers). The model learns the relationship between inputs and outputs to make predictions on new data.
#
# 2. Unsupervised Learning
#
# Unsupervised Learning is a type of Machine Learning where the data does not contain output labels. The model identifies hidden patterns, structures, or clusters within the data on its own.
#
# 3. Reinforcement Learning
#
# Reinforcement Learning is a type of Machine Learning where an agent learns by interacting with an environment and receives rewards for correct actions and penalties for incorrect actions. The goal is to maximize total reward over time.
#
# 4. Comparison Table with Real-World Examples
#
# | Learning Type          | Real-World Examples                           |
# | ---------------------- | --------------------------------------------- |
# | Supervised Learning    | Spam Detection, House Price Prediction        |
# | Supervised Learning    | Disease Prediction, Sentiment Analysis        |
# | Unsupervised Learning  | Customer Segmentation, Market Basket Analysis |
# | Unsupervised Learning  | Anomaly Detection, Image Clustering           |
# | Reinforcement Learning | Self-Driving Cars, Game Playing AI            |
# | Reinforcement Learning | Robotics Control, Stock Trading Bots          |
